# %%
import math
from matplotlib import pyplot as plt

def K(x):
    sinterm = math.sin( (math.pi/2.0) * ((x/3.0) -1.0) )
    unsqd = sinterm+1.0
    sqd = unsqd**2
    k = sqd+1.0
    return k
    
xs = range(7)
plt.plot(xs, [K(x) for x in xs])
