# %%
from collections import defaultdict, Counter
from copy import copy
from math import exp, sqrt
from random import random, shuffle, choice, randint, uniform

from keras import Input, Model
from keras.callbacks import EarlyStopping
from keras.constraints import non_neg, max_norm
import numpy
from numpy import array, mean, ones
from pandas import concat
from pandas import DataFrame
from keras.models import Sequential
from keras.layers import LSTM, multiply, subtract, add, Activation, Lambda, division, dot
from keras.layers import Dense, concatenate, MaxPooling1D, LocallyConnected1D, Reshape
from keras import backend as K
from keras import constraints
from keras.optimizers import Adam, RMSprop, SGD

from utils import generate_student_name
import random

nq = 12
n_traits = 5
tr_len = 100
tt_len = 10

# %%
generate_student_name()
# Out:
# 'PHUTHY CORE '

# %%
from keras import backend as K
from keras.constraints import Constraint
from keras.engine.topology import Layer
from keras import initializers

class WeightClip(Constraint):
    '''Clips the weights incident to each hidden unit to be inside a range
    '''
    def __init__(self, min_w=0, max_w=4):
        self.min_w = min_w
        self.max_w = max_w

    def __call__(self, p):
        return K.clip(p, self.min_w, self.max_w)

    def get_config(self):
        return {'name': self.__class__.__name__,
                'min_w': self.min_w,
                'max_w': self.max_w }


class ProductLayer(Layer):

    def __init__(self, output_dim, kernel_constraint=WeightClip(min_w=0.0, max_w=4.0), **kwargs):
        self.output_dim = output_dim
        super(ProductLayer, self).__init__(**kwargs)
        self.kernel_constraint = constraints.get(kernel_constraint)

    def build(self, input_shape):
        # Create a trainable weight variable for this layer.
        self.kernel = self.add_weight(name='kernel', 
                                      shape=(-1,self.output_dim),
                                      initializer=initializers.RandomUniform(minval=0.0, maxval=4.0), #.Constant(value=2.0),
                                      trainable=True,
#                                       constraint=self.kernel_constraint
                                     )
        
        super(ProductLayer, self).build(input_shape)  # Be sure to call this at the end

    def call(self, x):
        print("sk",self.kernel.shape)
        print("x", x.shape)
#         self.kernel = K.clip(self.kernel, self.cmin, self.cmax)
        z = K.concatenate([x,self.kernel], axis=2)
        print("internal z shape:", z.shape)
        p = K.prod(z, axis=2)
#         p = K.clip(p, self.cmin, self.cmax)
#         self.kernel = K.clip(self.kernel, self.cmin, self.cmax)

#         print("internal output shape:", p.shape)
        return p

    def compute_output_shape(self, input_shape):
        return (input_shape[0], self.output_dim)

# %%
class Question():
    def __init__(self, qix, nt=10):
        self.id = qix
        #self.qvals = [ int(uniform(0,1)>=0.5) for _ in range(nt) ]
        self.beta = randint(0,4)
        print("beta=",self.beta)

# %%
def generate_master_model(nq=10, ns=10):
    psi_sel = Input(shape=(ns,), name="user_selector")
    q_sel = Input(shape=(nq,), name="q_selector")
    #th_in = Input(shape=(ns,), name="user_theta")
#     th_in = Lambda(lambda x: K.ones(shape=(ns,))
    #b_in = Input(shape=(nq,))
#     b_in = Lambda(lambda x: K.ones(shape=(nq,))
#     th_in = K.ones(shape=ns)
#     b_in = K.ones(shape=nq)
    th_in = Input(shape=(ns,), name="dummy_th_in")
    b_in = Input(shape=(nq,), name="dummy_b_in")

    # N x ns .
    
    th_seld = multiply([psi_sel, th_in])
    b_seld = multiply([q_sel, b_in])
    
    th_layer = ProductLayer(ns)(th_seld) # introduce a trainable weight
    b_layer = ProductLayer(nq)(b_seld) # introduce a trainable weight
       
    this_th = Lambda(lambda x : K.sum(x))(th_layer)
    this_b = Lambda(lambda x : K.sum(x))(b_layer)
    
    dif = subtract([this_th,this_b])
    Prs = Lambda(lambda z: 1.0 / (1.0 + K.exp(-z)), name="Pr_sigmoid")(dif)
# Out:
#   File "<ipython-input-49-884e5db3598a>", line 2
#     psi_sel = Input(shape=(ns,), name="user_selector")
#     ^
# IndentationError: unexpected indent

# %%
def generate_student_struct(nt=10, nq=20):
    name = generate_student_name()
    theta = randint(0,4)
    mastery = [0 for _ in range(nq)]
    
    dict = {}
    dict["name"] = name
    dict["theta"] = theta
    dict["pred_theta_sc"] = 2.0
    
    return dict

# %%
def attempt_q(student, q: Question, update_weights=True):
    real_theta = student["theta"]
    real_beta = q.beta
    p = calculate_pass_probability(real_theta, real_beta)

    this_att = uniform(0,1)
    if (this_att <= p):
        passed=1
        student["mastery"][q.id] = 1
    else:
        passed=0

#     if update_weights:
#         pred_beta = q.pred_beta.get_weights()
# #     print(pred_beta)
#         pred_theta = student["pred_theta"].get_weights()
#         print("true th:", student["theta"])
#         print("true beta:", q.beta)
        
#         print("pre ptheta:", pred_theta)
#         print("pre pbeta:", pred_beta)
#         obi = numpy.ones(1)
#         print(obi)
#         es = EarlyStopping(monitor="loss", mode="auto")
#         q.model.fit([pred_theta[0][0], obi],[array([passed])], batch_size=1, verbose=0, epochs=10, callbacks=[es])
#         student["model"].fit([obi, pred_beta[0][0]],[array([passed])], batch_size=1, verbose=0, epochs=1, callbacks=[es])
#         print("post ptheta:", student["pred_theta"].get_weights()[0][0])
#         print("post pbeta:", q.pred_beta.get_weights()[0][0])
        
    return passed

# %%
def calculate_pass_probability(a, beta):
    z = (a - beta)
    print("z={}".format(z))
    try:
        p_pass = 1.0 / (1.0 + exp(-z))
        print("p_pass={}".format(p_pass))
    except OverflowError:
        p_pass = 0.0
    #print("real p_pass = {}".format(p_pass))
    return p_pass

# %%
random.seed(666)
master_qs = [Question(qix, n_traits) for qix in range(nq)]
for q in master_qs:
    print("Q:{}, difficulty={:.2f} across 1 components".format(q.id, q.beta))
# Out:
# beta= 3
# beta= 3
# beta= 3
# beta= 2
# beta= 4
# beta= 0
# beta= 4
# beta= 4
# beta= 2
# beta= 0
# beta= 0
# beta= 1
# Q:0, difficulty=3.00 across 1 components
# Q:1, difficulty=3.00 across 1 components
# Q:2, difficulty=3.00 across 1 components
# Q:3, difficulty=2.00 across 1 components
# Q:4, difficulty=4.00 across 1 components
# Q:5, difficulty=0.00 across 1 components
# Q:6, difficulty=4.00 across 1 components
# Q:7, difficulty=4.00 across 1 components
# Q:8, difficulty=2.00 across 1 components
# Q:9, difficulty=0.00 across 1 components
# Q:10, difficulty=0.00 across 1 components
# Q:11, difficulty=1.00 across 1 components

# %% [markdown]
# # Training
# This is where sh!t gets real.  We take our tr_len (1000?) students, and iterate over them 100 times to create 100,000 *complete examples* of a student attacking the curriculum.  The questions themselves are attacked in random order: the student has no intelligent guidance throught the material. (Obvious we may wish to provide that guidance at some point in the future.)
#
# Remember, there are only 12 exercises in the curriculum, so if the student is taking 60 or 70 goes to answer them all, that's pretty poor.  But some of these kids are dumb as lumber, so cut them some slack!  They will all get there in the end since by the CMU AFM practice will, eventually, make perfect!

# %%
MIN_THETA =0
MAX_THETA =4
def calc_better_theta(curr_theta, attempts):
    eps = 0.1
    sum_spread=0.0
    sum_info = 0.0
    for ix, (psi,q_i,pf) in enumerate(attempts):
        #go through the answered questions, sum up the difference in value vs expected value
        u_i = float( pf ) #cast bool of response to float i.e. {1,0}
        p_i_theta = calculate_pass_probability(curr_theta, q_i.pred_beta_sc)
        print("real/exp",u_i,p_i_theta)
        sum_spread += ( u_i - p_i_theta ) #TODO check this -ve sign
        #Then get the information function, tells us about precision of estimate
        info = p_i_theta * (1.0-p_i_theta)
        sum_info += info
    print("sum_spread=",sum_spread, "scaled_sp=",(sum_spread/sum_info))
    print("total info", sum_info)
    new_theta = curr_theta + (sum_spread / sum_info)
    print("raw new theta=", new_theta)

    if new_theta >= MAX_THETA:
        new_theta = MAX_THETA
        return new_theta
    elif new_theta <= MIN_THETA:
        new_theta = MIN_THETA
        return new_theta
    elif abs(new_theta - curr_theta) < eps:
        return new_theta # we're done, new theta is calc'd
    else:
        return calc_better_theta(new_theta, attempts) # iterate again

def calc_better_beta(curr_beta, attempts):
    eps = 0.1
    sum_spread=0.0
    sum_info = 0.0
    psis, qs, pfs = zip(*attempts)
    for ix,psi in enumerate(psis):
        th = psi["pred_theta_sc"]
        #go through the answered questions, sum up the difference in value vs expected value
        u_i = float( pfs[ix] ) #cast bool of response to float i.e. {1,0}
        p_i = calculate_pass_probability(th, curr_beta)
        print("Q real/exp",u_i,p_i)
        sum_spread += ( u_i - p_i ) #TODO check this -ve sign
        #Then get the information function, tells us about precision of estimate
        info = p_i * (1.0-p_i)
        sum_info += info
    print("Q sum_spread=",sum_spread, "scaled_sp=",(sum_spread/sum_info))
    print("Q total info", sum_info)
    new_beta = curr_beta - (sum_spread / sum_info)
    print("Q raw new beta=", new_beta)

    if new_beta >= MAX_THETA:
        new_beta = MAX_THETA
        return new_beta
    elif new_beta <= MIN_THETA:
        new_beta = MIN_THETA
        return new_beta
    elif abs(new_beta - curr_beta) < eps:
        return new_beta # we're done, new theta is calc'd
    else:
        return calc_better_beta(new_beta, attempts) # iterate again

# %%
Xs = {}
Tz = {}
ys = {}
alphas = {}
attempts = []
attempts_by_psi = {}
attempts_by_q = {}
no_tr_students = 200

random.seed(666)
psi_list = [ generate_student_struct() for _ in range(no_tr_students)]

mmodel = generate_master_model(nq = len(master_qs), ns=len(psi_list))

user_budget = 10
for run in range(1):
    print("----{}\n".format(run))
    for psi in psi_list:
        ct = 0
        psi["mastery"] = [0 for _ in range(nq)]
        qs = [ix for ix in range(len(master_qs))]
        print("* * * **** USER {}".format(psi["name"]))
        print("* * * * ** THETA {}".format(psi["theta"]))
            
        while(True):
            qix = random.choice(qs)
            q = master_qs[qix]
            passed=False
#             while not passed:
#             print(qix, q.pred_beta)
#             if qix not in Xs:
#                 Xs[qix]=[]
#                 Tz[qix]=[]
#                 ys[qix]=[]
#                 alphas[qix]=[]
            if psi["name"] not in attempts_by_psi:
                attempts_by_psi[psi["name"]]=[]
            
            if q not in attempts_by_q:
                attempts_by_q[q]=[]
    
            #print("attempting {}".format(q.id))
            passed = attempt_q(psi, q, update_weights=False)
            
            tup = (psi, q, passed)
            attempts.append(tup)
            attempts_by_psi[psi["name"]].append(tup)
            attempts_by_q[q].append(tup)
                        
            ct+=1
#             if passed:
                #print("passed")
            qs.remove(qix)

            if qs == []: # or ct>=user_budget:
                print("* ** *QFIN USER {}".format(psi["name"]))
                break
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-46-4e65afd7bf1a> in <module>()
#      11 psi_list = [ generate_student_struct() for _ in range(no_tr_students)]
#      12
# ---> 13 mmodel = generate_master_model(nq = len(master_qs), ns=len(psi_list))
#      14
#      15 user_budget = 10
#
# <ipython-input-39-29a793251537> in generate_master_model(nq, ns)
#      16     b_seld = multiply([q_sel, b_in])
#      17
# ---> 18     th_layer = ProductLayer(ns)(th_seld) # introduce a trainable weight
#      19     b_layer = ProductLayer(nq)(b_seld) # introduce a trainable weight
#      20
#
# ~/.venvs/isaac/lib/python3.6/site-packages/keras/engine/topology.py in __call__(self, inputs, **kwargs)
#     574                                          '`layer.build(batch_input_shape)`')
#     575                 if len(input_shapes) == 1:
# --> 576                     self.build(input_shapes[0])
#     577                 else:
#     578                     self.build(input_shapes)
#
# <ipython-input-45-ee59d5f45bb8> in build(self, input_shape)
#      33                                       initializer=initializers.RandomUniform(minval=0.0, maxval=4.0), #.Constant(value=2.0),
#      34                                       trainable=True,
# ---> 35                                       constraint=self.kernel_constraint)
#      36
#      37         super(ProductLayer, self).build(input_shape)  # Be sure to call this at the end
#
# ~/.venvs/isaac/lib/python3.6/site-packages/keras/legacy/interfaces.py in wrapper(*args, **kwargs)
#      85                 warnings.warn('Update your `' + object_name +
#      86                               '` call to the Keras 2 API: ' + signature, stacklevel=2)
# ---> 87             return func(*args, **kwargs)
#      88         wrapper._original_function = func
#      89         return wrapper
#
# ~/.venvs/isaac/lib/python3.6/site-packages/keras/engine/topology.py in add_weight(self, name, shape, dtype, initializer, regularizer, trainable, constraint)
#     398                             dtype=dtype,
#     399                             name=name,
# --> 400                             constraint=constraint)
#     401         if regularizer is not None:
#     402             self.add_loss(regularizer(weight))
#
# ~/.venvs/isaac/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py in variable(value, dtype, name, constraint)
#     383         v._uses_learning_phase = False
#     384         return v
# --> 385     v = tf.Variable(value, dtype=tf.as_dtype(dtype), name=name)
#     386     if isinstance(value, np.ndarray):
#     387         v._keras_shape = value.shape
#
# ~/.venvs/isaac/lib/python3.6/site-packages/tensorflow/python/ops/variables.py in __init__(self, initial_value, trainable, collections, validate_shape, caching_device, name, variable_def, dtype, expected_shape, import_scope, constraint)
#     211           dtype=dtype,
#     212           expected_shape=expected_shape,
# --> 213           constraint=constraint)
#     214
#     215   def __repr__(self):
#
# ~/.venvs/isaac/lib/python3.6/site-packages/tensorflow/python/ops/variables.py in _init_from_args(self, initial_value, trainable, collections, validate_shape, caching_device, name, dtype, expected_shape, constraint)
#     336           if not initial_value_shape.is_fully_defined():
#     337             raise ValueError("initial_value must have a shape specified: %s" %
# --> 338                              self._initial_value)
#     339
#     340         # If 'initial_value' makes use of other variables, make sure we don't
#
# ValueError: initial_value must have a shape specified: Tensor("product_layer_12/random_uniform:0", shape=(?, 200), dtype=float32)

# %%
obi = numpy.ones(1)
# print(obi)
es = EarlyStopping(monitor="loss", mode="auto")

# for _ in range(10):
#     for qn in attempts_by_q:
#         print("training {}, pre est beta = {}".format(qn.id, qn.pred_beta.get_weights()[0][0]))
#         thetas = array([ tup[0]["pred_theta"].get_weights()[0][0] for tup in attempts_by_q[qn]])
#         passed = array([ tup[2] for tup in attempts_by_q[qn] ])     
#         obi = numpy.ones(len(thetas))
#         qn.model.fit([thetas, obi],passed, batch_size=1, verbose=1, epochs=100, callbacks=[es])
#         print("{}, post est beta = {}. real {}".format(qn.id, qn.pred_beta.get_weights()[0][0], qn.beta))

#     for student_obj in psi_list:
#         student = student_obj["name"]
#         print("training {}".format(student))
#         print("Pre est {} has theta: {}".format(student, student_obj["pred_theta"].get_weights()[0][0]))
#         betas = array([ tup[1].pred_beta.get_weights()[0][0] for tup in attempts_by_psi[student] ])
#         passed = array([ tup[2] for tup in attempts_by_psi[student] ]).reshape(-1,1)
#         print(betas.shape)
#         print(passed.shape)
#         obi = numpy.ones(len(betas))
#         student_obj["model"].fit([obi, betas],passed, batch_size=1, verbose=1, epochs=100, callbacks=[es])
#         print("Post est {} has theta: {}, real {}".format(student, student_obj["pred_theta"].get_weights()[0][0], student_obj["theta"]))
    
random.seed(666)
calibration_mode = "NEURAL"
repz = (10 if calibration_mode=="NEURAL" else 1)
es = EarlyStopping(monitor="loss", mode="auto", min_delta=0.001)
student_att_ct = Counter()
pat_ct = 10
b_del_tol = 0.1
th_del_tol = 0.1
last_th_rmse = 1000
last_b_rmse = 1000
freeze_betas = False
freeze_thetas = False
for _ in range(100):
    if calibration_mode=="NEURAL":
        shuffle(master_qs)
        shuffle(psi_list)
        for q in master_qs:
            print(q.id)
            
            q_1hot = numpy.ones(len(master_qs))
            q_1hot[q.id] = 1

            b_del = tol+1
            thetas = [ tup[0]["pred_theta"].get_weights()[0][0] for tup in attempts_by_q[q]]
#             print("got  thetas")
            pfs = [ tup[2] for tup in attempts_by_q[q]]
#             print("got pfs")
            preb = q.pred_beta.get_weights()[0][0]
#             while(b_del > tol):
#             print("fit q")
            if not freeze_betas:
                q.model.fit([array(thetas), numpy.ones(len(thetas))],[array(pfs)], verbose=0, batch_size=1, epochs=100, callbacks=[es])
            postb = q.pred_beta.get_weights()[0][0]      
#                 b_del = abs(postb - preb)
#                 print("bdel",b_del)
            print("q{} true({}), preb {} postb {}".format(q.id, q.beta, preb, postb))

            if not freeze_thetas:
                psi_sublist = [tup[0] for tup in attempts_by_q[q]]
                for _student in psi_sublist:
                    th_del = tol+1
                    betas = [ tup[1].pred_beta.get_weights()[0][0] for tup in attempts_by_psi[_student["name"]]]
                    pfs = [ tup[2] for tup in attempts_by_psi[_student["name"]]]
                    preth= _student["pred_theta"].get_weights()[0][0] 
            #             while(th_del > tol):
            #             print("fit psi")
                    _student["model"].fit([numpy.ones(len(betas)), array(betas)],[array(pfs)], verbose=0, batch_size=1, epochs=100, callbacks=[es])
                    postth= _student["pred_theta"].get_weights()[0][0]
            #                 th_del = abs(postth - preth)
            #                 print("th_Del",th_del)
                    print("s{}: true({}), {} -> {}".format(_student["name"], _student["theta"], preth, postth))

    else:
        for q in master_qs:
            new_beta = calc_better_beta(q.pred_beta_sc, attempts_by_q[q])#[0:student_att_ct[student["name"]]])
            q.pred_beta_sc = new_beta
        for student in psi_list:
            theta = student["pred_theta_sc"]
            new_theta = calc_better_theta(theta, attempts_by_psi[student["name"]])
            student["pred_theta_sc"] = new_theta
            
            
    if calibration_mode=="NEURAL":
        th_rmse = mean([(s["theta"] - s["pred_theta"].get_weights()[0][0])**2 for s in psi_list])
        b_rmse = mean([(q.beta - q.pred_beta.get_weights()[0][0])**2 for q in master_qs])
    else:
        th_rmse = mean([(s["theta"] - s["pred_theta_sc"])**2 for s in psi_list])
        b_rmse = mean([(q.beta - q.pred_beta_sc)**2 for q in master_qs])

    if (last_b_rmse - b_rmse) > b_del_tol:
        last_b_rmse = b_rmse
        print("b mse:", b_rmse, "del:", (last_b_rmse - b_rmse))
    else:
        freeze_betas = True

    if (last_th_rmse - th_rmse) > th_del_tol:
        last_th_rmse = th_rmse
        input("th mse: {} del: {}".format(th_rmse,(last_th_rmse - th_rmse)))
    else:
        freeze_thetas = True
 
    if freeze_betas and freeze_thetas: # NO MORE CHANGE POSSIBLE!
        break

print("final beta rmse = {}".format(b_rmse))
print("final theta rmse = {}".format(th_rmse))
# Out:
# sNOCHA GAG : true(0), [ 2.99848032] -> [ 0.30300346]
# sTYHAD LOS : true(1), [ 3.27997017] -> [ 1.98007834]
# sYYNY GEKETH : true(0), [ 0.24511337] -> [ 0.48933557]
# sTHICH FETHAT : true(0), [ 3.71522617] -> [ 0.25398719]
# sTHECHY YAVATH : true(4), [ 3.4565835] -> [ 3.75649214]
# sWEJIC THON : true(4), [ 2.9414258] -> [ 3.92742848]
# sDEW BEG : true(4), [ 2.40742636] -> [ 3.83896303]
# sBYKUPH GYD : true(0), [ 3.78061199] -> [ 0.]
# sLUN DYH : true(3), [ 2.33408737] -> [ 3.99374747]
# sWOWYCH WINUB : true(1), [ 2.8631711] -> [ 1.911273]
# sGIHYN KAW : true(2), [ 1.88300085] -> [ 1.34014785]
# sHAGO THITHYR : true(2), [ 2.18468475] -> [ 2.44349599]
# sVALA FIVOT : true(0), [ 3.88628435] -> [ 1.0359534]
# sSEGAPH HOJ : true(3), [ 3.03456974] -> [ 2.75887609]
# sBOPHIF SUYI : true(0), [ 0.05613613] -> [ 1.30416965]
# sVUF SAHEF : true(4), [ 1.73440981] -> [ 3.24092293]
# sCYLA KOB : true(3), [ 2.78973103] -> [ 2.27006555]
# sCEJEB CUNI : true(2), [ 3.50475836] -> [ 2.77997351]
# sWIT LOC : true(4), [ 2.6069541] -> [ 3.7945807]
# sWINU GOLYR : true(3), [ 0.78680229] -> [ 4.]
# sFIPHI PHUP : true(3), [ 0.93848896] -> [ 3.26842189]
# sKUKY TILIG : true(4), [ 2.79563046] -> [ 4.]
# sVUPU BUVI : true(1), [ 2.29472923] -> [ 0.13442004]
# sJUTHYV THABYJ : true(4), [ 3.11162376] -> [ 4.]
# sDED WAN : true(2), [ 1.65928555] -> [ 2.85397577]
# sWES DISIPH : true(4), [ 3.65181541] -> [ 3.42953968]
# sFAV DOVUL : true(0), [ 2.68973589] -> [ 0.10098924]
# sFOF THODOJ : true(2), [ 3.24224472] -> [ 2.35267687]
# sCHACHYY FAPYT : true(4), [ 1.98950768] -> [ 3.3055234]
# sNAW VYMYY : true(1), [ 3.26282883] -> [ 2.32314181]
# sSOYIM YEM : true(4), [ 0.93686628] -> [ 3.7851088]
# sTAHE CIP : true(0), [ 1.43071604] -> [ 0.86036944]
# sMUBI CYTH : true(2), [ 2.39352036] -> [ 1.28006625]
# sJATH THOS : true(4), [ 0.53850603] -> [ 4.]
# sGECH GOL : true(0), [ 1.95847416] -> [ 0.27289683]
# sJECHE VAJEY : true(1), [ 1.54206038] -> [ 1.8192327]
# sKEW HIH : true(2), [ 0.93712616] -> [ 1.87857151]
# sCUJI ROR : true(1), [ 2.39146423] -> [ 1.86616051]
# sVYT LAB : true(0), [ 3.21664667] -> [ 0.3520661]
# sWEGU TUN : true(0), [ 1.7350421] -> [ 1.80322146]
# sDIRAS TYS : true(3), [ 0.97904158] -> [ 4.]
# sTHIHIT VYSUB : true(1), [ 1.41566849] -> [ 0.5863663]
# sMYV PHOCH : true(3), [ 3.75447226] -> [ 3.29999852]
# sLYBUK TOJA : true(3), [ 2.06348658] -> [ 2.75621557]
# sCYCHY YUYE : true(4), [ 0.87721968] -> [ 4.]
# sKYP TYNOR : true(3), [ 2.81991386] -> [ 2.85123134]
# sCHIWYJ TEKUTH : true(1), [ 3.24332237] -> [ 1.368976]
# sSICH PHAF : true(0), [ 3.61313915] -> [ 0.]
# sMOBOH LIJ : true(3), [ 2.67192221] -> [ 1.36132932]
# sJEWA KUJOV : true(0), [ 2.64580917] -> [ 0.04167237]
# sTUHO VUD : true(3), [ 1.92447996] -> [ 3.6674509]
# sLIG CYPH : true(4), [ 2.90005207] -> [ 3.98933601]
# sNOCEP CETU : true(3), [ 2.5075469] -> [ 2.72026634]
# sJIJOG PHESEG : true(0), [ 0.51260948] -> [ 1.23945034]
# sMUVA ROGEN : true(0), [ 2.98601294] -> [ 0.]
# sYIHA DARA : true(1), [ 1.54596567] -> [ 1.81766498]
# sWAPE SUHIL : true(4), [ 1.66784811] -> [ 3.20740604]
# sJUPH SOC : true(1), [ 1.01151657] -> [ 1.295717]
# sFARIT MAL : true(3), [ 2.13083649] -> [ 4.]
# sNYVY NIPEPH : true(1), [ 2.02932882] -> [ 0.75015408]
# sCHOMI JATHAP : true(0), [ 1.41633701] -> [ 0.67238313]
# sMAGOT JAPHYR : true(4), [ 2.26481867] -> [ 3.11218452]
# sGEB LETITH : true(4), [ 0.30415678] -> [ 4.]
# sSAGACH KIWI : true(3), [ 3.32234335] -> [ 3.65410972]
# sWAM NOBA : true(0), [ 3.93939161] -> [ 0.]
# sCAVEF MASY : true(0), [ 1.27464199] -> [ 0.80293185]
# sVYF SYTH : true(2), [ 0.5534749] -> [ 2.71654844]
# sNATA CHEPH : true(3), [ 1.32267237] -> [ 3.30093932]
# sCOG GOTO : true(2), [ 1.62005377] -> [ 0.74858701]
# sLAD MERAY : true(2), [ 3.29759359] -> [ 1.88798749]
# sJAPHE YEL : true(1), [ 3.51642656] -> [ 0.1969355]
# sCIHETH CHUPHI : true(4), [ 2.39311981] -> [ 3.68015146]
# sWER PHAJI : true(0), [ 1.56371355] -> [ 0.75878674]
# sSEV JIDA : true(4), [ 2.53708363] -> [ 4.]
# sSOGUY TUTHAW : true(0), [ 3.62063217] -> [ 0.12613206]
# sRUDY PIV : true(1), [ 3.73808098] -> [ 0.08553258]
# sTUFO HYCAR : true(3), [ 1.4206295] -> [ 3.29301763]
# sNIJU FEN : true(4), [ 1.16222] -> [ 4.]
# sFYY JYTO : true(4), [ 0.2981596] -> [ 4.]
# sFIR PHIDE : true(0), [ 3.44712448] -> [ 0.]
# sKOC TECH : true(4), [ 0.76407766] -> [ 3.68265414]
# sBEME HABOPH : true(3), [ 1.7107749] -> [ 2.62894487]
# sWED JOFIC : true(4), [ 0.16898394] -> [ 4.]
# sCAVE YOLU : true(4), [ 0.31973982] -> [ 3.19335103]
# sYITO JEBU : true(1), [ 2.09371424] -> [ 0.76845211]
# sCETOTH LAG : true(0), [ 0.16998482] -> [ 0.64437467]
# sPIMU MAKER : true(3), [ 2.45621634] -> [ 2.79827762]
# sVEGY RAHACH : true(1), [ 3.14085627] -> [ 1.43125248]
# sLYMU WAPI : true(0), [ 3.08966398] -> [ 1.25419545]
# sWEPHA VYPU : true(1), [ 1.19262695] -> [ 1.20342827]
# sGOSAM WIYU : true(2), [ 0.3635726] -> [ 1.16394436]
# sPHICIT NEWU : true(2), [ 3.11050606] -> [ 2.96188617]
# sNOR CHYGO : true(1), [ 1.38538647] -> [ 1.2292304]
# sYETHIS NYNOD : true(3), [ 3.03522205] -> [ 3.99939823]
# sGOLOL THOCHE : true(2), [ 0.4869709] -> [ 2.63232327]
# sPHORE WUMY : true(1), [ 2.79482269] -> [ 1.88800597]
# sCHAH GETY : true(3), [ 2.00534248] -> [ 3.1880753]
# sNIPH GET : true(4), [ 3.73841667] -> [ 4.]
# sHOM RENAN : true(2), [ 1.16307878] -> [ 2.78672767]
# sWECHI NIPHUW : true(2), [ 0.08007479] -> [ 1.21101844]
# sFOTU ROCAP : true(0), [ 0.77055311] -> [ 0.12267368]
# sRIP GUL : true(3), [ 2.18044043] -> [ 2.41952181]
# sTHEWA DECY : true(4), [ 1.36547565] -> [ 3.89227724]
# sNOMY WIPHA : true(4), [ 0.13275909] -> [ 4.]
# sCYN PHICHIV : true(2), [ 2.62211704] -> [ 2.07290387]
# sCHIJA WAPYN : true(1), [ 1.63814163] -> [ 1.25241816]
# sKIK BUGUN : true(2), [ 0.26664305] -> [ 2.44919562]
# sSUKI REBAB : true(2), [ 2.71260118] -> [ 1.28750396]
# sFICU WEJAP : true(3), [ 0.16628838] -> [ 2.69027925]
# sBONA HOS : true(0), [ 0.78343296] -> [ 0.71806544]
# sJOB ROKEM : true(3), [ 3.54961872] -> [ 3.71673083]
# sRIPAH JONOL : true(4), [ 1.9777894] -> [ 4.]
# sTHEHY TAWY : true(0), [ 1.84534359] -> [ 0.]
# sNISO YIF : true(2), [ 3.673141] -> [ 2.32373095]
# sVEL SODO : true(1), [ 0.2566905] -> [ 1.25455952]
# sVISA WAPY : true(2), [ 3.06296253] -> [ 1.95357263]
# sCYT NAPH : true(3), [ 2.71272707] -> [ 2.81886911]
# sPEPHEK LOTEF : true(1), [ 3.75124216] -> [ 1.50806379]
# sMOPHEC JAGU : true(4), [ 0.66774225] -> [ 3.80853367]
# sSOCHO BICHUR : true(0), [ 1.6240325] -> [ 0.26251227]
# sKIPHO KUCI : true(0), [ 1.4620018] -> [ 0.]
# sYYC CHIC : true(4), [ 2.08579063] -> [ 4.]
# sFYLA JYY : true(4), [ 1.13596153] -> [ 4.]
# sWOTH YAC : true(0), [ 3.65379953] -> [ 0.88843763]
# sMIGOM VYMY : true(0), [ 2.68174028] -> [ 1.36620498]
# sCARU CHAVOB : true(4), [ 2.34069824] -> [ 4.]
# sPHEBICH JIPOW : true(1), [ 1.0316515] -> [ 1.12759566]
# sLEJ CUCAPH : true(2), [ 0.08987617] -> [ 2.66960788]
# sSIW BIGAF : true(2), [ 0.96978378] -> [ 2.82815051]
# sTHYK VULO : true(1), [ 2.05734921] -> [ 1.36509418]
# sDOTHE LAKY : true(3), [ 1.84083605] -> [ 3.83157468]
# sYAYIN FEL : true(4), [ 1.05197382] -> [ 4.]
# sMAH GATHAY : true(0), [ 3.11384201] -> [ 1.86528826]
# sTYGEPH CHAG : true(3), [ 3.74148607] -> [ 3.71423078]
# sHYW CHYL : true(4), [ 0.56628227] -> [ 4.]
# sSAFYC PACH : true(2), [ 2.36953545] -> [ 2.00793409]
# sCHYP VOY : true(1), [ 1.43984461] -> [ 0.19975908]
# sYAMO JIRO : true(1), [ 0.80102348] -> [ 1.37913942]
# sKAKY VAKEN : true(1), [ 1.34039927] -> [ 2.22151327]
# sJUGA LISA : true(1), [ 0.934515] -> [ 0.12068288]
# sDUVA THON : true(1), [ 1.95497751] -> [ 0.888906]
# sCHOVIY YETHA : true(3), [ 2.0369339] -> [ 2.25133991]
# sHYBYY WYG : true(0), [ 1.42979479] -> [ 0.24963307]
# sTEDI JOKUTH : true(0), [ 2.59490728] -> [ 0.05783191]
# sCHUKE TUFI : true(1), [ 1.02298069] -> [ 0.73492676]
# sNUCHED HATH : true(0), [ 0.25048447] -> [ 1.74802566]
# sCEJAN HIGEPH : true(2), [ 3.92610884] -> [ 2.04364944]
# sDEDO SITHEG : true(0), [ 2.31360531] -> [ 0.]
# sFECA FIPY : true(0), [ 3.97836399] -> [ 0.44359002]
# sCIF SUNEP : true(1), [ 3.15107632] -> [ 1.59526002]
# sDYCOS RAS : true(0), [ 2.7240448] -> [ 0.88167799]
# sCIDI RECI : true(2), [ 3.87225246] -> [ 2.37279677]
# sVYPYM LITH : true(0), [ 2.58141136] -> [ 0.27447522]
# sLETA SIY : true(3), [ 1.43117523] -> [ 4.]
# sSET VATHO : true(3), [ 3.44918299] -> [ 3.26310158]
# sMAV WUWOD : true(2), [ 2.58173513] -> [ 2.23169017]
# sPES HUW : true(0), [ 0.91422701] -> [ 0.66048425]
# sTOB PHYF : true(1), [ 0.30834818] -> [ 1.42452765]
# sKATHA TONEB : true(1), [ 2.41143179] -> [ 1.30639946]
# sDUTYJ BOFY : true(0), [ 0.13419819] -> [ 0.16426775]
# sCHACH BIDUR : true(0), [ 3.55121613] -> [ 0.13354403]
# sTHICHIPH DOKU : true(2), [ 0.44915962] -> [ 3.28451538]
# sMISE VUYE : true(1), [ 2.73078632] -> [ 1.75895929]
# sCHIK TOFIM : true(0), [ 1.9363265] -> [ 1.50520396]
# sJYC THOBOC : true(1), [ 1.23019457] -> [ 1.2321074]
# sTOCH NASO : true(0), [ 0.38252687] -> [ 1.13338923]
# sRIH PHEHYK : true(3), [ 1.40516663] -> [ 3.10773301]
# sDAM BOCH : true(3), [ 1.38285732] -> [ 1.81491649]
# sJOCHO BOW : true(3), [ 1.83260155] -> [ 3.24718833]
# sCHYG PAK : true(1), [ 0.2446146] -> [ 0.]
# sCHOLA HULU : true(4), [ 1.50923252] -> [ 4.]
# sVOYUC FAJ : true(4), [ 2.32827425] -> [ 4.]
# sNYD KINO : true(2), [ 1.95674467] -> [ 2.36545253]
# sKAGE THYPY : true(4), [ 1.14991426] -> [ 4.]
# sWISUP FAD : true(3), [ 0.03561306] -> [ 4.]
# sKAFIN JOSIH : true(1), [ 2.0550046] -> [ 1.31257606]
# sTESI GAHAN : true(4), [ 3.04157782] -> [ 3.70168495]
# sTHEV WIPH : true(3), [ 1.61767817] -> [ 2.69645786]
# sLODO MEMUPH : true(0), [ 1.55316973] -> [ 1.31867957]
# sLESIC NAR : true(0), [ 3.60365152] -> [ 0.12722465]
# sWEGATH DOJE : true(3), [ 2.33971691] -> [ 2.67147064]
# sCAPHO THYT : true(2), [ 1.43284273] -> [ 2.71999955]
# sDATHACH BYTO : true(3), [ 2.40489054] -> [ 1.88588774]
# sJUCE MEWUCH : true(4), [ 3.4827323] -> [ 2.83580327]
# sJUHUM PEKU : true(2), [ 0.39599609] -> [ 2.82042241]
# sPHACHITH MUSUD : true(4), [ 1.85723209] -> [ 4.]
# sHASE HEFE : true(1), [ 3.95432901] -> [ 1.51001704]
# sTHOWAC TUMAB : true(0), [ 2.79757881] -> [ 0.13839784]
# sBIGYH CAFO : true(2), [ 0.57528067] -> [ 2.71288562]
# sPHEVU WOM : true(0), [ 2.55307245] -> [ 0.]

# %%
mse_ths = []
for psi in psi_list:
    real_th = psi["theta"]
    if calibration_mode=="NEURAL":
        pred_th = psi["pred_theta"].get_weights()[0][0]
    else:
        pred_th = psi["pred_theta_sc"]        
    mse_ths.append( (real_th - pred_th)**2 )
    print(psi["name"],":",real_th,"vs",pred_th)
print("MSE in theta: {}".format(mean(mse_ths)))

mse_bs = []
for q in master_qs:
    real_b = q.beta
    if calibration_mode=="NEURAL":
        pred_b = q.pred_beta.get_weights()[0][0]
    else:
        pred_b = q.pred_beta_sc
    mse_bs.append( (real_b - pred_b)**2 )
    print(real_b, "vs", pred_b)
print("MSE in beta: {}".format(mean(mse_bs)))
# Out:
# CAWED CUTO  : 0 vs [ 1.43137002]
# THAS LAMA  : 2 vs [ 3.13842344]
# VOS NOPHE  : 0 vs [ 0.01624745]
# TYGEPH CHAG  : 3 vs [ 2.69254637]
# MAY NUBON  : 4 vs [ 2.65961027]
# PHECHA VOD  : 2 vs [ 1.85923064]
# LOBAN SUWU  : 2 vs [ 1.30683517]
# DUMEK CHYCUW  : 4 vs [ 4.]
# HAGO THITHYR  : 2 vs [ 0.09910488]
# WOTH YAC  : 0 vs [ 2.53139877]
# YIGE HUF  : 3 vs [ 3.54270101]
# LOF CAP  : 0 vs [ 1.65312004]
# BONIF GEPO  : 0 vs [ 1.52775323]
# SEV JIDA  : 4 vs [ 1.1993494]
# YONOS SIPHI  : 0 vs [ 0.38031149]
# CEJAN HIGEPH  : 2 vs [ 3.43062305]
# WUTETH VURYB  : 1 vs [ 3.92609978]
# CEBOY MYF  : 1 vs [ 1.54486418]
# HUMAK KOWO  : 2 vs [ 3.29947162]
# SAC TUB  : 2 vs [ 3.22714806]
# GETHOC CHUGY  : 4 vs [ 2.77694082]
# LYTH GYCHAK  : 0 vs [ 0.90867782]
# KEL NEP  : 4 vs [ 0.72990131]
# DEDO SITHEG  : 0 vs [ 3.00751114]
# WIFYK BOFETH  : 0 vs [ 3.28139877]
# KOC TECH  : 4 vs [ 1.17192125]
# CHUGO KOLITH  : 4 vs [ 3.13905096]
# CEVOG PHAPHI  : 3 vs [ 3.67294765]
# DAL SUN  : 2 vs [ 2.60088944]
# RYKA NETU  : 3 vs [ 3.1335206]
# RULY MOG  : 1 vs [ 0.96174669]
# CHATHOT HYV  : 3 vs [ 3.49789619]
# JYCH VOSOM  : 3 vs [ 3.0985713]
# CHUYU LUJEN  : 0 vs [ 1.68956661]
# HYYE MIFOTH  : 1 vs [ 3.43708658]
# TEW SIM  : 2 vs [ 3.27865934]
# THUCU YOK  : 2 vs [ 0.56508493]
# LEYIB PHOF  : 0 vs [ 1.98841679]
# RYNO DOTEM  : 2 vs [ 3.63471031]
# HIM YYRATH  : 3 vs [ 1.38783026]
# FOTYD DYLE  : 1 vs [ 1.68625617]
# CHUW DOM  : 4 vs [ 1.18943691]
# DYCOS RAS  : 0 vs [ 0.77675104]
# VUFU MUT  : 2 vs [ 1.58345079]
# THOS TOPHE  : 2 vs [ 2.55214739]
# YEP TIK  : 2 vs [ 2.76358032]
# DUSY DYH  : 2 vs [ 3.27457094]
# YAYIN FEL  : 4 vs [ 2.41651487]
# MUK MYBYTH  : 1 vs [ 0.93447119]
# HYTHOP JYJAG  : 0 vs [ 0.22332144]
# RANOR KYBIN  : 1 vs [ 1.80459738]
# GUFY PHOTHY  : 3 vs [ 1.1626668]
# FUNO VENU  : 0 vs [ 0.13271448]
# TOPIB THOTI  : 4 vs [ 0.99413919]
# MIGOM VYMY  : 0 vs [ 3.18991137]
# RYB NACAT  : 0 vs [ 3.81873083]
# PHEPH COKIN  : 2 vs [ 2.09261918]
# KESO VEYE  : 4 vs [ 4.]
# TECHO VYC  : 3 vs [ 3.49556255]
# PENO BAPHAH  : 4 vs [ 3.71549273]
# MISE VUYE  : 1 vs [ 0.2942071]
# SIW BIGAF  : 2 vs [ 2.55126524]
# THECHY YAVATH  : 4 vs [ 2.62874603]
# BOS LOVYP  : 4 vs [ 4.]
# YUYUH TYWOH  : 1 vs [ 2.09310961]
# HIP VOMI  : 0 vs [ 3.80040216]
# YAVA MAY  : 3 vs [ 3.65419722]
# CHACHYY FAPYT  : 4 vs [ 1.76441336]
# PUR TUPI  : 3 vs [ 2.14099216]
# BYBY NELU  : 1 vs [ 2.50583577]
# YITO JEBU  : 1 vs [ 0.24220085]
# SORI MADYP  : 0 vs [ 1.19009066]
# RYTH DUCA  : 2 vs [ 3.15264559]
# RIBY SAWECH  : 2 vs [ 3.96574068]
# TYROC CHYGAV  : 4 vs [ 4.]
# FAT PHUS  : 0 vs [ 1.16036892]
# YYNY GEKETH  : 0 vs [ 3.10214424]
# PAGI NODYTH  : 3 vs [ 2.90612888]
# CYGE THAMAT  : 3 vs [ 2.10052633]
# FOTU ROCAP  : 0 vs [ 1.19884872]
# WEJIC THON  : 4 vs [ 3.95251942]
# LUN DYH  : 3 vs [ 3.67768955]
# RURAN WEVI  : 3 vs [ 2.41596794]
# FYV WYBE  : 0 vs [ 0.91128194]
# NOM VOF  : 2 vs [ 3.51030111]
# DAWY FECY  : 0 vs [ 0.38092709]
# PIPH TOM  : 4 vs [ 4.]
# CEJEB CUNI  : 2 vs [ 1.44825888]
# BONA HOS  : 0 vs [ 0.07103634]
# RYT VYHA  : 1 vs [ 1.98318636]
# SEGYB MAHY  : 1 vs [ 1.94446397]
# BAREP RYWYV  : 3 vs [ 0.81541872]
# HYR WAG  : 1 vs [ 1.57843173]
# KIMY KOTH  : 0 vs [ 1.47246313]
# DOBI RICH  : 4 vs [ 4.]
# PHEBICH JIPOW  : 1 vs [ 2.98369074]
# PYKY GIRU  : 2 vs [ 1.88581276]
# THEWA DECY  : 4 vs [ 3.60219717]
# VEDUK JYPO  : 3 vs [ 3.09944868]
# FARIT MAL  : 3 vs [ 2.83264542]
# WEPHA VYPU  : 1 vs [ 0.02841473]
# KYJO GURO  : 0 vs [ 1.55142355]
# SOGUY TUTHAW  : 0 vs [ 3.8827858]
# BAS TUJ  : 1 vs [ 1.21946526]
# BIM GYKOS  : 0 vs [ 0.68739307]
# MURI DETIV  : 0 vs [ 0.16486755]
# GEF KICOD  : 3 vs [ 3.94412661]
# CHIG CHOPI  : 4 vs [ 4.]
# SOC MADIM  : 3 vs [ 3.21553898]
# HEF SUL  : 2 vs [ 1.11417341]
# RIYIV WOPH  : 4 vs [ 3.44342089]
# YEJ MID  : 0 vs [ 0.02995813]
# PUCH THAPHUG  : 3 vs [ 0.60597706]
# NYKE PHACI  : 2 vs [ 1.48406649]
# DEW BEG  : 4 vs [ 0.7023263]
# MODIC NAWACH  : 3 vs [ 3.87763023]
# DOVIS BOGE  : 4 vs [ 3.46654081]
# GUKYPH CHADE  : 3 vs [ 1.23156214]
# RIWUH CHEH  : 1 vs [ 1.47133875]
# PHODY SEHA  : 2 vs [ 1.26357365]
# RANU NUTI  : 2 vs [ 3.25034189]
# NENI WEVIY  : 1 vs [ 1.31274605]
# MATU ROGE  : 4 vs [ 3.59686542]
# WEPHOL BUWIV  : 3 vs [ 3.67966318]
# WOWYCH WINUB  : 1 vs [ 0.0978055]
# NUJ THOREL  : 4 vs [ 0.91982365]
# LETYP VUMIB  : 0 vs [ 1.56350183]
# BIBO FACA  : 4 vs [ 1.21668291]
# CAPE LICHYL  : 4 vs [ 4.]
# GYJE PHIPHO  : 0 vs [ 3.61876106]
# GAKA PUCHA  : 0 vs [ 0.88867068]
# VIVUT NON  : 3 vs [ 3.93380737]
# NIJU FEN  : 4 vs [ 3.17207527]
# COVYP KUTHOK  : 4 vs [ 1.43056536]
# RUNYT WELY  : 4 vs [ 3.41106033]
# KYP TYNOR  : 3 vs [ 1.18025208]
# SUTITH SUNOCH  : 3 vs [ 3.24116158]
# GUC SOBOCH  : 3 vs [ 1.36495972]
# THEJU FATY  : 3 vs [ 3.76471972]
# WYYEL BUN  : 1 vs [ 0.13485575]
# DOJ JITH  : 0 vs [ 3.39867163]
# FOL TEC  : 0 vs [ 3.31212616]
# RIGE KAWY  : 2 vs [ 1.90192866]
# CHOGUC YORY  : 3 vs [ 1.3794055]
# MYVU VUTHO  : 0 vs [ 0.21508169]
# CHONIW JEWEJ  : 4 vs [ 3.4812355]
# HOTHAJ NIPHED  : 0 vs [ 0.10946274]
# DOCHA MUWU  : 0 vs [ 1.83900118]
# VEHO BOCO  : 1 vs [ 3.09214258]
# YOTHIF MED  : 4 vs [ 3.99768543]
# NUG KIHOTH  : 1 vs [ 2.39700413]
# NAC REYES  : 3 vs [ 3.30066395]
# LUKU HUFY  : 3 vs [ 3.5360136]
# BYFU PHICUR  : 0 vs [ 0.03849472]
# PHODUC VOWAL  : 1 vs [ 2.02491236]
# RYV CHULEK  : 4 vs [ 0.63927078]
# BEYECH VEWI  : 0 vs [ 1.45117807]
# DYBY YAYO  : 4 vs [ 1.02114868]
# DIF WEWAM  : 3 vs [ 0.64284658]
# FOYAS GEJYT  : 3 vs [ 0.143641]
# LYMU WAPI  : 0 vs [ 2.91358662]
# VACU JOCH  : 2 vs [ 2.26363039]
# LIJO THETHI  : 3 vs [ 3.53586721]
# HECH KINYW  : 4 vs [ 3.98698092]
# WAM NOBA  : 0 vs [ 3.78381824]
# LECHY BEH  : 2 vs [ 0.30227327]
# GOSEY WUGY  : 2 vs [ 0.69555664]
# PONICH GIKU  : 3 vs [ 2.84182739]
# HEM THOFYCH  : 0 vs [ 0.48944569]
# TYVA KYHA  : 1 vs [ 1.7972647]
# FICU WEJAP  : 3 vs [ 1.36634302]
# HYVI FYKO  : 2 vs [ 2.23325896]
# WETA SOLUD  : 3 vs [ 3.45874572]
# CHIWYJ TEKUTH  : 1 vs [ 2.58577585]
# SISI ROPHOK  : 0 vs [ 3.93140602]
# NYTIY RIY  : 3 vs [ 1.25140667]
# BOJU GUCHA  : 2 vs [ 3.82559013]
# WAV FEWI  : 4 vs [ 3.99102259]
# DOTHE LAKY  : 3 vs [ 0.7644763]
# MYV PHOCH  : 3 vs [ 1.234447]
# DIRAS TYS  : 3 vs [ 1.17926693]
# LIPI LALU  : 2 vs [ 1.88661623]
# BYNAN NIJ  : 1 vs [ 1.5791316]
# KICYL THOV  : 2 vs [ 2.65460134]
# LUS THYPIS  : 4 vs [ 3.96064591]
# KEJUK DUKY  : 0 vs [ 0.09336887]
# REP KOG  : 2 vs [ 1.29508114]
# RYC JYLEN  : 4 vs [ 3.20976615]
# PHUCU BEB  : 3 vs [ 2.63733721]
# CHOHE YAV  : 2 vs [ 2.7983942]
# HOR GOTHOL  : 1 vs [ 2.30442953]
# WEGATH DOJE  : 3 vs [ 0.94097567]
# PYWATH ROTH  : 0 vs [ 1.55896771]
# HAPHOF BEPHOK  : 1 vs [ 1.98157549]
# CAVEF MASY  : 0 vs [ 0.44361877]
# RIW LAT  : 4 vs [ 3.55765247]
# CICHU WEGAP  : 1 vs [ 1.02309227]
# LEYE YOPHAB  : 3 vs [ 2.54590082]
# HOT SYKIR  : 0 vs [ 0.96186215]
# CATH PIJAT  : 4 vs [ 3.99988508]
# SIJEY GICO  : 2 vs [ 2.78730583]
# FITO DIW  : 0 vs [ 2.98853874]
# TOB PHYF  : 1 vs [ 0.59368181]
# CHET LINAP  : 1 vs [ 1.67825997]
# THUF PAYAP  : 3 vs [ 1.89674568]
# RODU TADU  : 1 vs [ 0.83309984]
# MYTHUJ BETHA  : 0 vs [ 0.0984167]
# HEH WUC  : 3 vs [ 3.04235363]
# METU RAH  : 3 vs [ 3.84845281]
# RAWU CYD  : 0 vs [ 3.51514864]
# FAFI KAPHES  : 2 vs [ 1.46970177]
# TAWITH GISEM  : 1 vs [ 1.54947925]
# VEH NECY  : 0 vs [ 1.86784554]
# GYPHAC LYJY  : 2 vs [ 3.57854748]
# LYFO THADU  : 1 vs [ 3.6031065]
# YETHE KIRUM  : 4 vs [ 3.48749685]
# WER PHAJI  : 0 vs [ 0.55085182]
# BIGYH CAFO  : 2 vs [ 3.72301054]
# PHYNITH THUR  : 3 vs [ 1.82879305]
# RUR CHET  : 3 vs [ 2.78680658]
# PHUG DYYEN  : 3 vs [ 0.46555614]
# KIYO DYYUN  : 0 vs [ 2.17249441]
# TAV SUYU  : 1 vs [ 0.06490612]
# FUF BAH  : 4 vs [ 0.59677839]
# NYPH PACUL  : 4 vs [ 4.]
# LASA DUL  : 1 vs [ 1.06283712]
# HAPHU DOKO  : 1 vs [ 0.20063162]
# KYF REB  : 3 vs [ 1.16095591]
# SOPH YAV  : 2 vs [ 2.72950888]
# VYCY PHEF  : 0 vs [ 2.52498388]
# JIP NOMO  : 1 vs [ 2.13716674]
# LYTE YUPAV  : 2 vs [ 2.25130033]
# RARYK CHOL  : 3 vs [ 0.85573578]
# DYHOG YOPH  : 0 vs [ 2.00870204]
# VIBOCH PHIK  : 0 vs [ 0.82365996]
# CECUT CHIH  : 3 vs [ 4.]
# CYLA KOB  : 3 vs [ 1.29311705]
# LIWUR SUD  : 3 vs [ 3.06680679]
# KID FYHI  : 0 vs [ 1.40738165]
# CHYNUB DAL  : 2 vs [ 0.48621416]
# YUC NAPO  : 3 vs [ 3.24486566]
# SIN YEPHI  : 2 vs [ 2.54496765]
# CHOGUH FEWY  : 3 vs [ 4.]
# DAGIS DUT  : 0 vs [ 0.84094328]
# PUVI PHAPA  : 0 vs [ 0.26092958]
# TIPH WOKY  : 4 vs [ 3.00305367]
# CHYHEK WAV  : 1 vs [ 3.58452463]
# CHEPHUB YUNA  : 4 vs [ 2.58117533]
# CIHETH CHUPHI  : 4 vs [ 2.19041204]
# KIK BUGUN  : 2 vs [ 2.65538168]
# LUR DYFU  : 3 vs [ 3.09811997]
# THASU PHYWOK  : 3 vs [ 3.9230473]
# TED HIVUG  : 1 vs [ 1.92282581]
# YICHIN YEPE  : 4 vs [ 2.76809263]
# NISO YIF  : 2 vs [ 0.70354128]
# THOG RIRAS  : 2 vs [ 0.5895586]
# JAVIP THAFY  : 3 vs [ 4.]
# KAYI PUB  : 4 vs [ 4.]
# RYDEH CHYLE  : 0 vs [ 1.43047667]
# MACA MITAJ  : 3 vs [ 1.49431658]
# YEPH GYNYP  : 1 vs [ 1.81539106]
# SEGA THAB  : 1 vs [ 2.72538686]
# BATIT SOPHY  : 0 vs [ 2.33636761]
# HIDY KYVEB  : 4 vs [ 0.55487156]
# VUPU BUVI  : 1 vs [ 1.57017374]
# JIKON YAWE  : 1 vs [ 1.07190323]
# VECOCH SUPHUPH  : 1 vs [ 0.84971476]
# DIMI THANECH  : 0 vs [ 2.36755347]
# CHYP VOY  : 1 vs [ 2.40007114]
# BUJUN HEVIN  : 0 vs [ 0.25373888]
# CYH THODO  : 0 vs [ 3.86011171]
# WOTAV VEYITH  : 2 vs [ 3.17997789]
# POW GALOH  : 2 vs [ 2.3568821]
# FUH GULA  : 3 vs [ 1.24318695]
# MECYB RYVAW  : 3 vs [ 2.23943806]
# VEL SODO  : 1 vs [ 2.97607565]
# BOPHIF SUYI  : 0 vs [ 3.1383996]
# FIPHI PHUP  : 3 vs [ 0.28475714]
# HYCHYM CAPH  : 3 vs [ 1.28557491]
# MOPHEC JAGU  : 4 vs [ 2.16000319]
# SOYIM YEM  : 4 vs [ 0.41595507]
# COCHA YOJOL  : 0 vs [ 0.99709755]
# THIRE COTH  : 4 vs [ 4.]
# HUDO DOVY  : 3 vs [ 2.68534541]
# SOFY THYFYP  : 2 vs [ 3.75350189]
# WIYA THEPY  : 2 vs [ 3.10501432]
# YIK SUPHI  : 2 vs [ 2.72359896]
# JALU PHIHI  : 2 vs [ 3.25909042]
# RUCHOK FICEP  : 4 vs [ 1.9119544]
# DOPH CULYS  : 1 vs [ 0.78467852]
# NYD KINO  : 2 vs [ 0.5337925]
# NAD PUH  : 4 vs [ 3.98614693]
# NEJO TIBY  : 2 vs [ 3.70726848]
# SEWE GUMOD  : 0 vs [ 0.27879572]
# SYR ROM  : 0 vs [ 0.12285166]
# DICI TYJO  : 4 vs [ 0.0578723]
# PUTHOY CAPHU  : 0 vs [ 1.91644573]
# PAWIL TAVO  : 2 vs [ 2.24666524]
# KAVYN YAGUY  : 1 vs [ 0.49460697]
# FAME MIG  : 4 vs [ 3.5415802]
# TENAT HINYC  : 4 vs [ 3.66165328]
# POTH PHAHU  : 1 vs [ 0.12483168]
# TYMOW YYNU  : 2 vs [ 3.85567951]
# NUCHED HATH  : 0 vs [ 0.82624865]
# PHAMIPH KISA  : 2 vs [ 1.83726192]
# CAPHO THYT  : 2 vs [ 3.04956198]
# FYCHO THOHET  : 4 vs [ 3.97076058]
# JYYIY PHAPHYT  : 2 vs [ 2.84847522]
# JAY HISA  : 3 vs [ 0.70925283]
# SYCHA REPAM  : 2 vs [ 1.1758275]
# WETHO TUNA  : 1 vs [ 1.63908374]
# CHESI SIWI  : 3 vs [ 3.22933769]
# CHAW FESO  : 1 vs [ 3.7966609]
# PETH WIY  : 0 vs [ 1.57838678]
# SOM CHACHUCH  : 4 vs [ 3.23637056]
# TUPHE POCHA  : 1 vs [ 3.37874126]
# POC PHICU  : 2 vs [ 3.80046177]
# CUCH FYSOF  : 3 vs [ 3.95170999]
# RUDY PIV  : 1 vs [ 0.0571804]
# THINOG BUKU  : 1 vs [ 3.11251545]
# GIDUJ PUP  : 4 vs [ 0.0723877]
# NUNO WYLUD  : 0 vs [ 2.70063829]
# VOCHI YYW  : 3 vs [ 2.74024081]
# KUKY TILIG  : 4 vs [ 0.64269066]
# MOCHOT WUPHAV  : 1 vs [ 2.48054934]
# MAGOT JAPHYR  : 4 vs [ 0.10985565]
# YUCHO YEN  : 4 vs [ 2.82818699]
# HARA BETHIL  : 3 vs [ 0.06877089]
# CHUME FUMIF  : 2 vs [ 3.14588881]
# CHITO FIY  : 4 vs [ 4.]
# PAW BOTHY  : 0 vs [ 3.67581224]
# BEW FEPHUN  : 3 vs [ 1.61269331]
# JUPHA CEKAH  : 2 vs [ 2.46650147]
# YIM SEJI  : 1 vs [ 0.71618026]
# CAGAM LUF  : 3 vs [ 2.05579901]
# TOCHAH MYTI  : 4 vs [ 4.]
# WYC CHOPH  : 4 vs [ 4.]
# KAGE THYPY  : 4 vs [ 1.14660883]
# FYPH WECHUV  : 0 vs [ 0.15378718]
# YOK WUDO  : 3 vs [ 0.27795792]
# RIP GUL  : 3 vs [ 3.48235559]
# DEBU NUNOY  : 1 vs [ 1.47709644]
# THESY MYMA  : 0 vs [ 0.03524613]
# MAGO WISO  : 1 vs [ 2.54566574]
# PIS PIJEM  : 0 vs [ 2.15487766]
# WED JOFIC  : 4 vs [ 3.83340836]
# NARO BYJ  : 2 vs [ 2.52478409]
# THUGUCH DAYET  : 3 vs [ 3.97006321]
# FAL YEH  : 2 vs [ 2.29496837]
# NUM HIGO  : 0 vs [ 0.01478999]
# TUFO HYCAR  : 3 vs [ 0.61447477]
# HYSET GOPHA  : 0 vs [ 0.19879341]
# LOP LEW  : 4 vs [ 3.96293879]
# LOCHAD GUCUY  : 1 vs [ 2.71226072]
# CYDIP CIYYR  : 0 vs [ 2.20520115]
# BYY KYDU  : 1 vs [ 2.59636259]
# JYC THOBOC  : 1 vs [ 3.33686113]
# WEHI YOL  : 2 vs [ 3.36986828]
# SYR KOKUP  : 1 vs [ 1.13017225]
# GYT SOBACH  : 3 vs [ 3.13929486]
# THIBU KULU  : 0 vs [ 0.58242559]
# FICHUG GICHOPH  : 3 vs [ 3.28541303]
# JUCU THYNU  : 2 vs [ 3.65860796]
# PASOP WUSUT  : 4 vs [ 1.26438093]
# SARU KUYA  : 0 vs [ 0.86104012]
# FAPY HOTUY  : 4 vs [ 4.]
# PHORE WUMY  : 1 vs [ 1.36917067]
# PHACHITH MUSUD  : 4 vs [ 1.1175127]
# HUB BOHIJ  : 0 vs [ 1.57227063]
# KYTOF MIW  : 0 vs [ 3.70399189]
# WIY CONUK  : 3 vs [ 0.72745323]
# CHUTHU CUTHYV  : 0 vs [ 0.84232873]
# CINUF CHYNY  : 0 vs [ 3.74025488]
# CYT NAPH  : 3 vs [ 0.78515482]
# SIGEH COM  : 3 vs [ 2.78227448]
# DIH SIVE  : 3 vs [ 3.62102771]
# DIPH LOD  : 3 vs [ 3.71319222]
# MYM WYPHUTH  : 1 vs [ 1.92671692]
# DOJEV VOK  : 1 vs [ 2.14246511]
# PHUTHY CORE  : 0 vs [ 0.10997053]
# SEGUC RUH  : 2 vs [ 0.16247463]
# THOKU CAT  : 0 vs [ 1.54798663]
# DIJU TUCHIG  : 4 vs [ 0.05777264]
# MAV WUWOD  : 2 vs [ 3.28344774]
# MEC VUTUN  : 0 vs [ 0.05117512]
# PHID KUFUR  : 4 vs [ 1.90781546]
# HOTUTH PHECOS  : 2 vs [ 2.87021899]
# TAHE CIP  : 0 vs [ 3.05465364]
# SACE LAYOK  : 2 vs [ 3.47277927]
# YYSON COTUK  : 0 vs [ 0.60461378]
# BUW JEKUPH  : 1 vs [ 0.14346889]
# HUHIW POC  : 2 vs [ 1.08642197]
# CHIJA WAPYN  : 1 vs [ 1.79841661]
# VIHY CHEPAK  : 1 vs [ 3.34775209]
# KOK RACHE  : 0 vs [ 1.45568001]
# KEN CHOK  : 3 vs [ 1.81746864]
# TETHEK YIF  : 1 vs [ 1.4559803]
# NEK SILAN  : 4 vs [ 2.37336969]
# DED WAN  : 2 vs [ 0.98391438]
# HACH NOVE  : 3 vs [ 1.23777199]
# KOTH CAJA  : 1 vs [ 2.95880318]
# JECH TOT  : 3 vs [ 3.56567526]
# CHOVIY YETHA  : 3 vs [ 3.46717405]
# TENI BIHO  : 1 vs [ 2.79498959]
# VUSUB YIM  : 4 vs [ 3.90491843]
# HICH HIWE  : 1 vs [ 0.10516977]
# GOSAM WIYU  : 2 vs [ 0.71583176]
# HUJYR JED  : 4 vs [ 2.33490801]
# GECH GOL  : 0 vs [ 3.3861022]
# GUS HECH  : 0 vs [ 0.10295296]
# KEW HIH  : 2 vs [ 2.73926687]
# RATHO FOTHYH  : 2 vs [ 1.57444715]
# VEVE VOJOB  : 2 vs [ 3.19689298]
# HUCHAPH VEPH  : 2 vs [ 3.56113195]
# LYBUK TOJA  : 3 vs [ 3.82392883]
# CHEM WUNIR  : 4 vs [ 3.43322372]
# CHICOPH PHANA  : 2 vs [ 2.53171372]
# ROVI FAFOW  : 2 vs [ 3.71450377]
# CETOTH LAG  : 0 vs [ 3.00915384]
# YUFO DAG  : 3 vs [ 3.714149]
# JUPH SOC  : 1 vs [ 0.9823184]
# MAH GATHAY  : 0 vs [ 3.49461126]
# THEM VAG  : 3 vs [ 3.46694326]
# RUSO CEDIM  : 0 vs [ 2.08109808]
# TANO WICHE  : 3 vs [ 2.80593538]
# BYJ SIMA  : 2 vs [ 3.8130064]
# CHUM HIPYV  : 4 vs [ 2.09593678]
# GYJ WILE  : 0 vs [ 0.29023647]
# FECA FIPY  : 0 vs [ 0.92150784]
# NASUS CINED  : 2 vs [ 3.06051517]
# WIPH PHOB  : 1 vs [ 1.58123207]
# JEPE FUT  : 4 vs [ 2.79174185]
# LYCOM KUFYB  : 1 vs [ 3.39631844]
# PHUFE VAF  : 2 vs [ 1.21075392]
# NEDAN HOWY  : 1 vs [ 0.76544619]
# JUR SAG  : 2 vs [ 3.46529913]
# FUH TEH  : 1 vs [ 2.77752638]
# THAP WUN  : 4 vs [ 3.84729075]
# DAHU THUV  : 4 vs [ 4.]
# SAFYC PACH  : 2 vs [ 3.41045713]
# YEY TYTE  : 1 vs [ 2.93522835]
# TENI JAHIV  : 2 vs [ 1.50572491]
# NIT MIJUS  : 2 vs [ 2.36579156]
# THIKIB MOM  : 2 vs [ 1.46864128]
# GIGYT BUFA  : 4 vs [ 3.99236083]
# TUS WYJ  : 1 vs [ 2.04795671]
# SYSO SEJ  : 4 vs [ 0.27232409]
# SAMU TUK  : 4 vs [ 2.71584749]
# KUW LIB  : 3 vs [ 2.54088163]
# SEVY VUYA  : 2 vs [ 0.8360548]
# ROC WEWYC  : 4 vs [ 3.69138455]
# PERYJ CHEFY  : 4 vs [ 1.48785686]
# HUS DINO  : 3 vs [ 2.22330761]
# CYB THICIP  : 3 vs [ 3.69727087]
# BEPE NYC  : 3 vs [ 2.09130621]
# PETON PYG  : 0 vs [ 2.1034112]
# JECHE VAJEY  : 1 vs [ 2.31650209]
# LETA SIY  : 3 vs [ 2.26143742]
# FOF THODOJ  : 2 vs [ 3.86157513]
# TOV LAW  : 0 vs [ 1.60792875]
# PUPHY COSUK  : 3 vs [ 3.19238043]
# CEVUL JYTH  : 0 vs [ 0.96277177]
# JYTH CHOWOS  : 0 vs [ 0.08026838]
# YOMU TYCHYL  : 1 vs [ 1.13279915]
# TYR CUK  : 1 vs [ 1.40393937]
# THEV WIPH  : 3 vs [ 3.8477788]
# FOFOB MITH  : 1 vs [ 2.60066509]
# KIBI GYW  : 1 vs [ 0.51334524]
# GESE SAPH  : 3 vs [ 1.54001093]
# VIJUH RUPU  : 1 vs [ 0.10451651]
# SAGACH KIWI  : 3 vs [ 2.3789115]
# GEB LETITH  : 4 vs [ 1.46607113]
# DAFA RYDOY  : 2 vs [ 2.71313024]
# BYKUPH GYD  : 0 vs [ 1.44380045]
# CUJI ROR  : 1 vs [ 3.11443949]
# LUVOCH CAJ  : 3 vs [ 3.23325205]
# DOF VUPUC  : 0 vs [ 0.12931015]
# PIMO REFUF  : 4 vs [ 3.96808004]
# KUL PYY  : 4 vs [ 3.13078237]
# KAKY VAKEN  : 1 vs [ 3.47795773]
# YIHA DARA  : 1 vs [ 1.37577534]
# CHEN THOP  : 4 vs [ 3.97833538]
# TEBAL FUFI  : 3 vs [ 0.14588785]
# LIG CYPH  : 4 vs [ 0.57318592]
# CHACAD KUVAG  : 2 vs [ 0.94772911]
# BUB GAGUL  : 1 vs [ 3.43140841]
# DOGAL THOTHU  : 1 vs [ 2.16105366]
# GYNIF YEYOJ  : 1 vs [ 2.31656909]
# REYEY THOJU  : 2 vs [ 0.44204044]
# FIGI PYTU  : 2 vs [ 2.42181897]
# LOCHA NOWYK  : 0 vs [ 0.77543724]
# RIHUJ KUR  : 2 vs [ 2.0655663]
# REYAP WEPUM  : 0 vs [ 1.57222223]
# RIMA HAB  : 2 vs [ 1.32564831]
# KIYYN PYGU  : 3 vs [ 3.10395575]
# MYYEP THOV  : 2 vs [ 0.64236212]
# COR HOR  : 2 vs [ 2.61732531]
# PEY JUS  : 3 vs [ 2.86693311]
# CYCHY YUYE  : 4 vs [ 2.54056931]
# JIJIR NAFA  : 1 vs [ 0.01873933]
# NIPHYC KEC  : 0 vs [ 2.4275763]
# PHUH THABA  : 2 vs [ 2.44284439]
# YEFICH DERAL  : 2 vs [ 2.64207721]
# KULUTH THUGU  : 4 vs [ 3.6378603]
# WEYECH BAK  : 4 vs [ 1.16290188]
# VUF SAHEF  : 4 vs [ 2.9867878]
# WELI JARYM  : 2 vs [ 3.43979073]
# PHOSUJ TUP  : 0 vs [ 3.7819891]
# JILU PHYP  : 3 vs [ 1.93705654]
# GETAT GAVU  : 1 vs [ 2.17611933]
# RILYTH YOR  : 1 vs [ 2.38134193]
# CHIG YOR  : 1 vs [ 1.20697069]
# WOJ YYN  : 4 vs [ 2.91528082]
# THAD SIWAY  : 4 vs [ 1.77694368]
# JYV VEYI  : 0 vs [ 3.38440084]
# THAJETH TUJA  : 2 vs [ 1.68962765]
# CHOMI JATHAP  : 0 vs [ 2.98626947]
# WYTHE VYKO  : 1 vs [ 0.86244887]
# DIP DATHI  : 2 vs [ 2.25872946]
# BUKEC MASOC  : 0 vs [ 1.47249436]
# KOY HAYEB  : 1 vs [ 2.46603847]
# JERO DEJUL  : 2 vs [ 0.73427105]
# CAWER DAWOTH  : 3 vs [ 3.24264097]
# SON SUJUP  : 0 vs [ 1.25114286]
# PUPHUJ SOCOPH  : 0 vs [ 2.19296598]
# CUBI THAJE  : 3 vs [ 2.71256423]
# JIJOG PHESEG  : 0 vs [ 2.77730608]
# PHAYATH THUBI  : 4 vs [ 3.65098262]
# NODU CHIG  : 2 vs [ 0.58491516]
# DIPHUG NANOJ  : 3 vs [ 2.74676609]
# COH CHIFO  : 4 vs [ 4.]
# PYCHO LYL  : 3 vs [ 3.52772927]
# ROJ ROLOL  : 3 vs [ 1.74340439]
# CUY RUFYS  : 3 vs [ 2.92479563]
# PETH RITYF  : 1 vs [ 3.56685114]
# PIWOK PAHA  : 3 vs [ 2.18360853]
# CHIF MEPHY  : 4 vs [ 1.84875488]
# FIR PHIDE  : 0 vs [ 2.39810562]
# PHYG THANES  : 0 vs [ 1.95337915]
# ROPHU KUCH  : 1 vs [ 0.84565866]
# CHACHYN NOS  : 1 vs [ 2.10479641]
# KAFIN JOSIH  : 1 vs [ 1.0605979]
# VALA FIVOT  : 0 vs [ 1.27124071]
# SEGAPH HOJ  : 3 vs [ 2.73494864]
# WIFE BIYE  : 4 vs [ 3.95759606]
# MOBOH LIJ  : 3 vs [ 1.21000147]
# WOBI YIPHYM  : 4 vs [ 2.68863821]
# NIBIR PHIFAS  : 3 vs [ 3.62721419]
# HAPHIT HUBUP  : 0 vs [ 0.18194611]
# PHICHU RAJ  : 1 vs [ 1.57024658]
# RUFO PHAGAY  : 3 vs [ 3.73447585]
# FIGO KOJO  : 4 vs [ 4.]
# MOMIP VIHYCH  : 0 vs [ 0.92615455]
# MALOK TIKAV  : 0 vs [ 0.81912708]
# RETU DOT  : 4 vs [ 2.80849028]
# THYRYJ JYK  : 1 vs [ 0.75340223]
# SENOD PYH  : 0 vs [ 0.88834316]
# DIBIPH DUHE  : 3 vs [ 2.42515564]
# SYFUG HIHI  : 4 vs [ 4.]
# TUW SETIL  : 3 vs [ 3.23864627]
# YAMO JIRO  : 1 vs [ 0.3250885]
# JASAG WIY  : 1 vs [ 1.98364735]
# FYY JYTO  : 4 vs [ 3.16597939]
# CIBE YID  : 1 vs [ 3.7421031]
# PEPHOF JOHA  : 2 vs [ 2.77743769]
# WIWY WYPH  : 2 vs [ 2.79471087]
# JIL VEJU  : 1 vs [ 1.46726668]
# DYGAM HEF  : 4 vs [ 0.07484341]
# JIPA DELUR  : 4 vs [ 0.93316507]
# HAF KOFA  : 0 vs [ 1.40951777]
# LALYC MOPIP  : 4 vs [ 4.]
# SEDIH FAJ  : 0 vs [ 1.38543177]
# JUGA LISA  : 1 vs [ 0.20273256]
# JYCHY WYMUS  : 2 vs [ 1.30927753]
# HUWYS CHUTH  : 2 vs [ 2.43340206]
# THUD DECIW  : 0 vs [ 0.42803431]
# CHYM SEB  : 0 vs [ 0.76196575]
# CHACH BIDUR  : 0 vs [ 0.55715704]
# HYW CHYL  : 4 vs [ 2.95677376]
# THYGE WOJ  : 0 vs [ 1.31448829]
# RUGYJ HOS  : 3 vs [ 0.09763432]
# LUW FITO  : 3 vs [ 3.5223577]
# LEPHO RIKI  : 4 vs [ 3.95553184]
# HOFUC WUCH  : 1 vs [ 3.04146886]
# FEV RYH  : 1 vs [ 2.56691933]
# MYBOG DYPAJ  : 2 vs [ 2.08034372]
# YYNY NID  : 2 vs [ 2.78601742]
# GES JATHET  : 4 vs [ 4.]
# PYY RICH  : 2 vs [ 2.36503839]
# GOLOL THOCHE  : 2 vs [ 3.20362663]
# NIF DIVA  : 0 vs [ 1.75969124]
# TIHYCH SAS  : 1 vs [ 2.83827591]
# PANIL CHALI  : 2 vs [ 2.01767421]
# JOYUY KOPHO  : 2 vs [ 2.31342363]
# VIYEV CHELO  : 3 vs [ 1.65169525]
# PUCH HON  : 0 vs [ 0.09332605]
# BOTES YEYEL  : 3 vs [ 3.57397676]
# KUR PIVA  : 0 vs [ 0.92509353]
# BUT SIPU  : 3 vs [ 3.17390561]
# ROTHI CHYYYS  : 0 vs [ 0.0567892]
# WAV DICHY  : 1 vs [ 3.50109243]
# WECHI NIPHUW  : 2 vs [ 1.86718225]
# LUJ THOCHA  : 0 vs [ 0.92434078]
# GEP HYLYL  : 1 vs [ 2.47241402]
# MIBU CHIHYK  : 1 vs [ 2.67004275]
# YECH WERE  : 1 vs [ 2.05889463]
# CYW DES  : 0 vs [ 2.98406553]
# FEM TEV  : 1 vs [ 0.02771752]
# VYPYM LITH  : 0 vs [ 2.79876566]
# DOCHUP RUPH  : 1 vs [ 2.47481394]
# SYK VIK  : 4 vs [ 4.]
# CERIL JYPHY  : 4 vs [ 3.49005079]
# DUDEJ PUNO  : 1 vs [ 0.28306198]
# GOJY FEYE  : 0 vs [ 3.71461105]
# GUM GIPH  : 4 vs [ 3.9591732]
# BUPHI BOLU  : 0 vs [ 0.924209]
# PEP CAME  : 4 vs [ 2.33628225]
# DATHACH BYTO  : 3 vs [ 2.10979223]
# VEFO HUTH  : 1 vs [ 1.60455346]
# CHIK TOFIM  : 0 vs [ 3.03585625]
# TUHO VUD  : 3 vs [ 2.54768372]
# TESI GAHAN  : 4 vs [ 0.5290122]
# RYTA SECEP  : 1 vs [ 2.51605153]
# KORO LUH  : 3 vs [ 2.87313104]
# RIH PHEHYK  : 3 vs [ 0.85431719]
# KIPHO KUCI  : 0 vs [ 0.71706963]
# CUPHA FOM  : 3 vs [ 1.89368629]
# HIB GIC  : 2 vs [ 1.57811642]
# CULA GIHAM  : 2 vs [ 1.88324773]
# BEWIY CUCE  : 0 vs [ 1.45079994]
# PHOROG REN  : 2 vs [ 3.76306176]
# WIS NEHU  : 1 vs [ 1.45663452]
# REJU RYMAH  : 1 vs [ 1.51542068]
# PHIBUH YYTA  : 4 vs [ 0.18850088]
# PHATH YAHUN  : 0 vs [ 1.18525887]
# POCOG THEM  : 1 vs [ 2.88046241]
# DANU VYKU  : 1 vs [ 1.84369183]
# RORYT DAJID  : 0 vs [ 1.95719337]
# YAD THUB  : 0 vs [ 3.35479593]
# WAC CHYSE  : 2 vs [ 1.99636269]
# KIVO THACH  : 4 vs [ 0.18148994]
# FAV DOVUL  : 0 vs [ 3.86558962]
# WAS YIKYR  : 0 vs [ 1.23136663]
# WICHY DEPUS  : 0 vs [ 1.46896362]
# MABA SET  : 0 vs [ 0.02083759]
# HUTU RISE  : 1 vs [ 2.00466752]
# WEPI KETHA  : 0 vs [ 1.25398111]
# KEWE KEMU  : 0 vs [ 0.46375799]
# CHYJE VIMO  : 2 vs [ 2.31292009]
# SYK TOR  : 1 vs [ 2.53601551]
# SYG CEVY  : 2 vs [ 2.57296371]
# BAJ PHYK  : 0 vs [ 3.7687993]
# YYC CHIC  : 4 vs [ 3.38135815]
# WEGU TUN  : 0 vs [ 3.20810413]
# YAG JUFO  : 1 vs [ 1.2363739]
# RETH YAREM  : 4 vs [ 0.01337624]
# CIDI RECI  : 2 vs [ 3.50695658]
# TYHA KEG  : 0 vs [ 1.51512182]
# TULOB CHEV  : 4 vs [ 0.58892155]
# KIJIJ NER  : 2 vs [ 0.45266199]
# TAPOR THOHY  : 0 vs [ 1.60718417]
# BEN GYNY  : 2 vs [ 2.46432686]
# YUKI REMES  : 0 vs [ 0.93420333]
# CHYF KIMO  : 3 vs [ 3.16557598]
# PHYHIS RYR  : 1 vs [ 1.95102525]
# FES CHUTE  : 3 vs [ 4.]
# MEG CHISY  : 1 vs [ 1.9433533]
# PUL THELAT  : 2 vs [ 2.0104723]
# HILYM WAKA  : 4 vs [ 4.]
# THUV JUPH  : 1 vs [ 1.93421459]
# HYM KYT  : 3 vs [ 3.99576569]
# YETHIS NYNOD  : 3 vs [ 3.2678628]
# VEGY RAHACH  : 1 vs [ 0.29758263]
# NOR CHYGO  : 1 vs [ 0.81517506]
# WIT LOC  : 4 vs [ 3.46023989]
# CHOV POP  : 3 vs [ 2.26819062]
# JELO RIR  : 1 vs [ 3.08890533]
# CULYW CHIY  : 0 vs [ 2.93316126]
# LODO MEMUPH  : 0 vs [ 0.20481586]
# RORU LACHO  : 0 vs [ 1.29273129]
# PHATH YOPY  : 0 vs [ 1.96690881]
# KOKA FUGUT  : 4 vs [ 3.50824642]
# DOKUY BAYER  : 1 vs [ 2.54520035]
# JODAL FECY  : 0 vs [ 1.98919487]
# JYPHI SELU  : 4 vs [ 4.]
# CUL YAS  : 1 vs [ 2.61036587]
# PER THORA  : 3 vs [ 3.18142843]
# HADA JUSA  : 2 vs [ 2.52042627]
# TAHEP SUCO  : 0 vs [ 1.02395773]
# SOD GYGI  : 2 vs [ 2.40269971]
# PYV MOSAL  : 0 vs [ 0.14408375]
# GEDOP LOCH  : 4 vs [ 2.96861124]
# LAHUC PUN  : 2 vs [ 3.60640287]
# RYV VYJY  : 0 vs [ 3.39155436]
# PEM THYCA  : 3 vs [ 3.11016846]
# RIPAH JONOL  : 4 vs [ 3.02738667]
# WISUP FAD  : 3 vs [ 1.79403877]
# PHAFU VEROP  : 0 vs [ 3.59779692]
# KIPH SYN  : 0 vs [ 1.45523453]
# WUM LILI  : 4 vs [ 4.]
# MUMI THOFEC  : 2 vs [ 3.10565042]
# THICHIPH DOKU  : 2 vs [ 3.56241179]
# TYHAD LOS  : 1 vs [ 2.28842831]
# JATH THOS  : 4 vs [ 2.9282918]
# PHATYT THIV  : 0 vs [ 1.65725386]
# WAV JEDIY  : 0 vs [ 0.37867546]
# CYN PHICHIV  : 2 vs [ 3.16186619]
# FAMO RIW  : 2 vs [ 0.50767231]
# HYBYY WYG  : 0 vs [ 2.71538925]
# TESY RUTAR  : 0 vs [ 0.03455039]
# PHAW RYRI  : 3 vs [ 3.3388834]
# SOLUL SIFE  : 4 vs [ 1.64769316]
# MUROTH LYCHI  : 0 vs [ 1.62832165]
# ROYY BAWEF  : 4 vs [ 2.6731329]
# PHICIT NEWU  : 2 vs [ 1.8626976]
# VYF YUKAG  : 0 vs [ 0.11372272]
# VEG NERUR  : 0 vs [ 2.37053251]
# FUJ KECYCH  : 2 vs [ 1.96703863]
# VID HEN  : 0 vs [ 2.71408939]
# BUKUR BUPH  : 1 vs [ 3.69992828]
# DYYU LICH  : 4 vs [ 0.11583042]
# FYDETH MAFEPH  : 0 vs [ 0.27140045]
# SEL YEKY  : 4 vs [ 3.95378685]
# CHOLA HULU  : 4 vs [ 2.17825174]
# LIVEH PELOCH  : 3 vs [ 3.60681081]
# SUB PUD  : 4 vs [ 3.55860496]
# KIVI KALA  : 2 vs [ 0.80776405]
# CARU CHAVOB  : 4 vs [ 0.54941225]
# CHOTH MOW  : 3 vs [ 3.93246436]
# PEPHEK LOTEF  : 1 vs [ 2.28349829]
# CHIRE HIR  : 2 vs [ 1.33900988]
# FAWO KECUCH  : 1 vs [ 0.65523958]
# LYVY YATH  : 1 vs [ 0.35408163]
# WINU GOLYR  : 3 vs [ 1.18414164]
# HOKUW MUFYW  : 1 vs [ 0.32867527]
# GIHYN KAW  : 2 vs [ 2.14764118]
# VEG GEW  : 1 vs [ 1.72837973]
# TALA PHIFO  : 2 vs [ 3.50483131]
# RANO RINU  : 4 vs [ 4.]
# NAW VYMYY  : 1 vs [ 3.77538776]
# MUCAF RYCUM  : 2 vs [ 2.00628376]
# CHEDYS MITHO  : 0 vs [ 0.54276943]
# THICH FETHAT  : 0 vs [ 3.53828001]
# HOM RENAN  : 2 vs [ 3.37308645]
# LOCHYF JACHAY  : 0 vs [ 1.42268431]
# TUC BOD  : 1 vs [ 0.62574291]
# HEY BUBE  : 3 vs [ 1.44437551]
# NEPE GAR  : 4 vs [ 4.]
# SERIY TEJ  : 4 vs [ 1.53437805]
# FIT LUTHO  : 0 vs [ 2.61621714]
# FAS NEVE  : 2 vs [ 1.63938773]
# SICAW SYPHUCH  : 2 vs [ 1.97672462]
# KOH JICA  : 4 vs [ 1.46929598]
# CHAPHOP RYKYK  : 2 vs [ 1.51668787]
# THIRAP FELI  : 0 vs [ 1.37304974]
# DYME HEKA  : 4 vs [ 3.39640093]
# FEWUT CEW  : 1 vs [ 2.08180118]
# SOCHO BICHUR  : 0 vs [ 1.05024862]
# VYF SYTH  : 2 vs [ 3.60801458]
# THOWAC TUMAB  : 0 vs [ 1.32612753]
# RUP JANYT  : 4 vs [ 4.]
# HEJU TICI  : 3 vs [ 2.79355097]
# MUFU MAVI  : 2 vs [ 3.54120398]
# WUPH THUTHUM  : 3 vs [ 1.79011774]
# PIKIP PHYDOJ  : 2 vs [ 3.13321924]
# NOMY WIPHA  : 4 vs [ 1.12547827]
# POVAK GIHU  : 2 vs [ 3.76434326]
# VEJ WATHEV  : 2 vs [ 2.30284929]
# CHELUD LURI  : 4 vs [ 4.]
# PES HUW  : 0 vs [ 1.38409567]
# BIT WYR  : 3 vs [ 3.05385208]
# GASA PONI  : 4 vs [ 4.]
# PUK VYGA  : 2 vs [ 0.25175858]
# DUVA THON  : 1 vs [ 2.99789762]
# THALY NUK  : 3 vs [ 0.82574368]
# MIWA JOPHIG  : 3 vs [ 3.58670568]
# TOMY MYD  : 0 vs [ 0.02388486]
# GOYU KUPI  : 2 vs [ 2.44094443]
# DES GUTE  : 3 vs [ 3.96729517]
# PHATY HOK  : 2 vs [ 2.8902154]
# KYKY CICE  : 0 vs [ 2.04914713]
# CHIV DIV  : 1 vs [ 0.81082773]
# FUSA CHAPHAT  : 3 vs [ 2.93872833]
# VISA WAPY  : 2 vs [ 3.90237522]
# TASU JATHA  : 0 vs [ 1.72371531]
# CAN RYN  : 1 vs [ 3.50194883]
# MULUB MIL  : 4 vs [ 3.4595089]
# CHINEL MECH  : 3 vs [ 3.60089254]
# JEJ WED  : 2 vs [ 1.8768425]
# CHIJ THOGU  : 4 vs [ 3.87727833]
# WEPER YAWU  : 2 vs [ 2.40111279]
# JOCHO BOW  : 3 vs [ 0.75943851]
# THOFUF WUC  : 0 vs [ 0.08798552]
# RIPH CHIJIY  : 4 vs [ 4.]
# MEH BEREC  : 1 vs [ 3.38482094]
# BAG CHYPHET  : 0 vs [ 1.54303288]
# CIPHI TOTHEJ  : 3 vs [ 3.5596199]
# SET VATHO  : 3 vs [ 1.83860159]
# PHIRAY WIPIPH  : 3 vs [ 2.67094254]
# PHEMIT VOMY  : 3 vs [ 1.43784475]
# THOPI KYKI  : 3 vs [ 1.32268429]
# VAPUF FOC  : 0 vs [ 1.19148922]
# GEGE FUTY  : 1 vs [ 2.81791544]
# FIKU CON  : 1 vs [ 1.39982367]
# MIMI NOPY  : 1 vs [ 1.88185537]
# JILA NEL  : 4 vs [ 1.56264019]
# LYBY CHYT  : 3 vs [ 0.82863903]
# MOTYW PYTE  : 2 vs [ 1.66898632]
# THYW WUHY  : 0 vs [ 0.27736378]
# BEME HABOPH  : 3 vs [ 0.83734703]
# PHUHU MEG  : 0 vs [ 3.6810956]
# PHOFE TOY  : 3 vs [ 1.59363461]
# CAM ROJI  : 1 vs [ 3.70962667]
# SAVIR POCHAK  : 4 vs [ 3.99122429]
# WUGU THEFA  : 1 vs [ 0.88534838]
# BUYAL BAY  : 1 vs [ 0.91744685]
# HYKE KYP  : 3 vs [ 3.67642021]
# DYJ THIC  : 2 vs [ 2.80244446]
# BOH MYTYG  : 4 vs [ 0.71332979]
# PHUT GALO  : 4 vs [ 0.18118715]
# THYK VULO  : 1 vs [ 3.62084293]
# CHIYYS YIT  : 0 vs [ 3.63691854]
# GYPHY CHYD  : 2 vs [ 2.8205843]
# MOF GOMA  : 4 vs [ 0.71576881]
# GEBOM DOCO  : 4 vs [ 3.57227087]
# MIC LASAW  : 1 vs [ 3.8584671]
# GICHOH CHOVAH  : 1 vs [ 0.90113705]
# PHYMO MACO  : 3 vs [ 1.38056564]
# PHACHE PHETAK  : 1 vs [ 0.90177459]
# NIKUG KUVI  : 2 vs [ 3.78133821]
# SAS DISU  : 2 vs [ 1.4956913]
# JESA KEPA  : 4 vs [ 4.]
# CAVY CIM  : 2 vs [ 1.35585976]
# NAPH BUTOB  : 3 vs [ 3.52347565]
# VYVI YAHY  : 2 vs [ 2.31182599]
# YYP PER  : 0 vs [ 2.39385319]
# DASI TYLOTH  : 2 vs [ 2.7417345]
# PHOB COR  : 1 vs [ 1.37065291]
# YET MOYIR  : 3 vs [ 3.10119891]
# TUV KUTHON  : 4 vs [ 4.]
# PUB CHAYE  : 0 vs [ 2.0533123]
# HEP KEC  : 3 vs [ 3.22403097]
# TIM CAPA  : 0 vs [ 0.99424171]
# BYC YAW  : 1 vs [ 1.99227655]
# HAPHO SADO  : 3 vs [ 2.86446309]
# SIMOF BADU  : 3 vs [ 2.85352731]
# SICH PHAF  : 0 vs [ 3.74575281]
# FYMA JAD  : 0 vs [ 1.46181238]
# FONO VOM  : 1 vs [ 3.44973373]
# PAFIW PHUKOY  : 1 vs [ 1.53738427]
# RAYO CHES  : 1 vs [ 0.67450428]
# PYNU CHERO  : 4 vs [ 2.28033829]
# MUVA ROGEN  : 0 vs [ 1.69474554]
# CIF SUNEP  : 1 vs [ 2.09289932]
# MENU TACHYV  : 2 vs [ 3.69238949]
# PABEL FUP  : 0 vs [ 0.05753835]
# NOCHA GAG  : 0 vs [ 0.06975031]
# VYR YEY  : 3 vs [ 2.26654387]
# SOH CHUWO  : 4 vs [ 1.37595177]
# VYN WYC  : 1 vs [ 0.75854063]
# CHITHU SIG  : 1 vs [ 2.10331297]
# DENO ROY  : 3 vs [ 3.31912327]
# CIC GIJI  : 3 vs [ 2.63156128]
# DOL CHINIR  : 2 vs [ 0.60668898]
# MIK CHOFEK  : 3 vs [ 3.67940784]
# LYCH DUJE  : 1 vs [ 1.29543018]
# TUVOCH DEYOS  : 4 vs [ 2.5198617]
# GAKYR YOLUY  : 1 vs [ 1.92883921]
# ROK COGOB  : 2 vs [ 2.39091444]
# PIWE FEPAK  : 1 vs [ 1.32716274]
# BOHI DAN  : 2 vs [ 2.84342384]
# SAMUW PHOFA  : 3 vs [ 3.65959334]
# JYSUTH HIDETH  : 1 vs [ 1.59647751]
# GIRE FUCIP  : 0 vs [ 1.19000673]
# WES DISIPH  : 4 vs [ 2.44919491]
# BIH NAS  : 2 vs [ 1.97799623]
# VIVI NETHO  : 0 vs [ 0.42937374]
# MOVAS GUTI  : 4 vs [ 2.67122412]
# GECHYS LUCA  : 0 vs [ 1.54893422]
# HASE HEFE  : 1 vs [ 2.90108776]
# MAGUS FATHAS  : 3 vs [ 0.37571859]
# COWOH WOKE  : 2 vs [ 3.74670506]
# TYSAJ NELIN  : 4 vs [ 3.71492529]
# KATHA TONEB  : 1 vs [ 0.41767311]
# WOWOCH WIH  : 4 vs [ 3.94888425]
# THEHY TAWY  : 0 vs [ 3.55982399]
# CHAGIS PHET  : 4 vs [ 1.77298641]
# REW PHOJ  : 0 vs [ 2.64825249]
# JIJ YUSYT  : 4 vs [ 0.29667139]
# LAD MERAY  : 2 vs [ 1.54289055]
# PIMU MAKER  : 3 vs [ 0.03703117]
# DUTYJ BOFY  : 0 vs [ 0.55188084]
# DYCH TAYEB  : 2 vs [ 2.18398333]
# RAROH DALUT  : 1 vs [ 1.37657261]
# YOCA YILA  : 2 vs [ 2.37104273]
# WEBI RAKA  : 1 vs [ 2.47724175]
# NUVI HARYPH  : 0 vs [ 3.7560544]
# LEFY LYTHYV  : 3 vs [ 1.99047804]
# CHYG PAK  : 1 vs [ 3.08362007]
# PADO PHUTH  : 1 vs [ 0.96146029]
# TISOC LEKEY  : 1 vs [ 2.84423971]
# PHENY JOPHI  : 1 vs [ 0.91016912]
# LUYO JUHUF  : 2 vs [ 1.93115103]
# SUTY LOPYH  : 3 vs [ 3.26837754]
# VYT LAB  : 0 vs [ 1.59368849]
# CEW KEYOM  : 2 vs [ 2.83667636]
# PACH LUBEJ  : 1 vs [ 0.13348764]
# YAJAG TYRAB  : 4 vs [ 4.]
# SITE HUG  : 2 vs [ 3.66496038]
# PAPHIPH BID  : 1 vs [ 2.49786758]
# DYG WOLA  : 2 vs [ 2.36896992]
# JEWA KUJOV  : 0 vs [ 0.36194754]
# JEL LOTHAT  : 1 vs [ 2.27107239]
# BESIF NUL  : 2 vs [ 1.10542536]
# SEK TUNIS  : 0 vs [ 0.]
# CHAH GETY  : 3 vs [ 2.84989405]
# JUHUM PEKU  : 2 vs [ 3.26680374]
# TEFEB NEBEP  : 4 vs [ 3.94926715]
# CATH SAG  : 0 vs [ 0.97998083]
# NUFYR KABA  : 1 vs [ 0.77293807]
# CENUL BULY  : 2 vs [ 3.23123193]
# NIPH GET  : 4 vs [ 1.66757154]
# CHUDU RODYV  : 2 vs [ 2.50086951]
# SAPO SEBUW  : 3 vs [ 3.55682063]
# TOB GUTH  : 0 vs [ 0.98697883]
# FYLA JYY  : 4 vs [ 0.45589685]
# TOCH NASO  : 0 vs [ 1.06876755]
# TOHIM JOT  : 0 vs [ 0.79478359]
# NOYA YUPHOP  : 1 vs [ 1.68419075]
# COG GOTO  : 2 vs [ 2.57891035]
# RAS LIG  : 4 vs [ 1.17136383]
# PHOJEY BASYCH  : 4 vs [ 3.30747938]
# WAPE SUHIL  : 4 vs [ 0.13888502]
# CAJ FIJ  : 3 vs [ 0.22333622]
# CAVE YOLU  : 4 vs [ 3.80486631]
# KOW TASIW  : 0 vs [ 1.26354802]
# CYT BAG  : 2 vs [ 2.37637734]
# YIH VICHEJ  : 3 vs [ 2.36217928]
# SECHUY VUPH  : 0 vs [ 1.5816735]
# HYY FOT  : 3 vs [ 4.]
# BEGI NUTE  : 3 vs [ 1.28996706]
# NATA CHEPH  : 3 vs [ 1.5437994]
# FURYCH TULU  : 2 vs [ 2.79878354]
# LEJ CUCAPH  : 2 vs [ 1.14881897]
# BETHEJ VALUS  : 1 vs [ 2.51253414]
# THIHIT VYSUB  : 1 vs [ 3.43199158]
# SOPHI MUD  : 1 vs [ 1.67000175]
# CHUKE TUFI  : 1 vs [ 3.89591742]
# DYLO JYPH  : 0 vs [ 1.56636727]
# HIYUCH YOTHAH  : 0 vs [ 2.94996858]
# VOYUC FAJ  : 4 vs [ 0.78336382]
# VENE FYPHY  : 4 vs [ 0.93748569]
# JUCE MEWUCH  : 4 vs [ 2.67934704]
# NOCEP CETU  : 3 vs [ 3.17366982]
# DYGI BARA  : 4 vs [ 0.93253326]
# FOLU WOSU  : 4 vs [ 4.]
# BODUR GONAL  : 4 vs [ 3.96748376]
# GYKU BYPH  : 1 vs [ 1.44359148]
# FIGUTH KOTHI  : 1 vs [ 1.47481966]
# PHYCHYTH HEBO  : 4 vs [ 4.]
# HYCHA SOCA  : 0 vs [ 0.05649785]
# TEPHAL KEB  : 3 vs [ 1.13886452]
# SOPH DOVE  : 3 vs [ 2.93186998]
# FUPH BARIK  : 3 vs [ 1.93639946]
# THIRY GUKI  : 3 vs [ 0.13772869]
# PAVUPH MEGA  : 0 vs [ 0.7607488]
# PHECHAD SOS  : 3 vs [ 2.76617193]
# NYVY NIPEPH  : 1 vs [ 0.81861544]
# JUTHYV THABYJ  : 4 vs [ 3.17380524]
# THEMYS POV  : 0 vs [ 1.98597753]
# TEDI JOKUTH  : 0 vs [ 2.0943079]
# COT DIC  : 3 vs [ 3.63976741]
# NAM PHYVU  : 3 vs [ 3.54906106]
# DYR NUCHAN  : 0 vs [ 0.77784348]
# DAM BOCH  : 3 vs [ 0.16311026]
# YYFUF HOKO  : 1 vs [ 1.34030819]
# RYWOB TEF  : 4 vs [ 0.73218489]
# LIPOCH PHODE  : 0 vs [ 0.03943535]
# THYDOP WAP  : 2 vs [ 3.41004801]
# THAWE CIC  : 0 vs [ 2.11232185]
# PHALYS FID  : 1 vs [ 2.2345624]
# WYF WIWER  : 1 vs [ 2.8452487]
# CUKER PEPHU  : 1 vs [ 1.89073813]
# JOB ROKEM  : 3 vs [ 0.31948042]
# DEFYH KOCAG  : 2 vs [ 0.69555855]
# JAPHE YEL  : 1 vs [ 1.4071455]
# LOCHY DALI  : 1 vs [ 0.79609966]
# NIC RUDOTH  : 4 vs [ 2.41003466]
# CIK DUPE  : 1 vs [ 2.84991455]
# LESIC NAR  : 0 vs [ 2.72731447]
# FOCHA PUPHY  : 0 vs [ 1.72771358]
# RITHES MEDAS  : 3 vs [ 2.30076075]
# PHEVU WOM  : 0 vs [ 1.04972553]
# SUKI REBAB  : 2 vs [ 2.35569239]
# BAC VEGA  : 4 vs [ 1.45332003]
# MAJIM MUR  : 0 vs [ 2.76685619]
# MUBI CYTH  : 2 vs [ 1.55263186]
# HYS NOCYL  : 4 vs [ 4.]
# CITHU YYTU  : 3 vs [ 0.2024231]
# VIKEN MULOTH  : 3 vs [ 2.04398751]
# MSE in theta: 2.4369754791259766
# 2 vs [ 2.67018771]
# 3 vs [ 2.1849966]
# 4 vs [ 2.45025921]
# 1 vs [ 3.18012333]
# 2 vs [ 2.90738726]
# 4 vs [ 1.28510141]
# 0 vs [ 3.77736616]
# 3 vs [ 3.0162425]
# 0 vs [ 3.85503292]
# 4 vs [ 1.80151415]
# 0 vs [ 3.54878283]
# 3 vs [ 3.42716026]
# MSE in beta: 5.266811847686768
